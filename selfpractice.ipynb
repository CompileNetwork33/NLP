# %%
import pandas as pd 
import re
import nltk

# %%
data = pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\NLP techadd\file_name.csv")
data.head()

# %%
data.describe()

# %%
data.info()

# %%
data.shape

# %%
data.sample()

# %%
data.isna().sum()

# %%
data =data.drop('Text',axis=True)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=12854, step=1)

# %%
data.dtypes
# Out:
# Title                  str
# Political Lean         str
# Score                int64
# Id                     str
# Subreddit              str
# URL                    str
# Num of Comments      int64
# Date Created       float64
# dtype: object

# %%
nltk.download('punkt')
nltk.download('stopwords')
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"http\S+"," ",text)
    text = re.sub(r"[a-Az-Z]\s"," ",text)
    text = word_tokenize(text)
    words = [word for word in words if word not in stopwords]
    words = [lemmatizer.lemmatize(words)for word in words]

    return ' '.join(words)

# %%
clean_text

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(
    max_features=8000,
    ngram_range=(2,3),
    stop_words='english',
    min_df=3
)
x = tfidf.fit_transform('Title')
