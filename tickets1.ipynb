# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\kashi\OneDrive\图片\Desktop\NLP techadd\tickets.zip")
df.head()
# Out:
#    Ticket ID        Customer Name              Customer Email  Customer Age  \
# 0          1        Marisa Obrien  carrollallison@example.com            32
# 1          2         Jessica Rios    clarkeashley@example.com            42
# 2          3  Christopher Robbins   gonzalestracy@example.com            48
# 3          4     Christina Dillon    bradleyolson@example.org            27
# 4          5    Alexander Carroll     bradleymark@example.com            67
#
#   Customer Gender Product Purchased Date of Purchase      Ticket Type  \
# 0           Other        GoPro Hero       2021-03-22  Technical issue
# 1          Female       LG Smart TV       2021-05-22  Technical issue
# 2           Other          Dell XPS       2020-07-14  Technical issue
# 3          Female  Microsoft Office       2020-11-13  Billing inquiry
# 4          Female  Autodesk AutoCAD       2020-02-04  Billing inquiry
#
#              Ticket Subject  \
# 0             Product setup
# 1  Peripheral compatibility
# 2           Network problem
# 3            Account access
# 4                 Data loss
#
#                                   Ticket Description  \
# 0  I'm having an issue with the {product_purchase...
# 1  I'm having an issue with the {product_purchase...
# 2  I'm facing a problem with my {product_purchase...
# 3  I'm having an issue with the {product_purchase...
# 4  I'm having an issue with the {product_purchase...
#
#                Ticket Status                                     Resolution  \
# 0  Pending Customer Response                                            NaN
# 1  Pending Customer Response                                            NaN
# 2                     Closed   Case maybe show recently my computer follow.
# 3                     Closed  Try capital clearly never color toward story.
# 4                     Closed                    West decision evidence bit.
#
#   Ticket Priority Ticket Channel  First Response Time   Time to Resolution  \
# 0        Critical   Social media  2023-06-01 12:15:36                  NaN
# 1        Critical           Chat  2023-06-01 16:45:38                  NaN
# 2             Low   Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3             Low   Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Low          Email  2023-06-01 00:12:42  2023-06-01 19:53:42
#
#    Customer Satisfaction Rating
# 0                           NaN
# 1                           NaN
# 2                           3.0
# 3                           3.0
# 4                           1.0

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %%
df.shape
# Out:
# (8469, 17)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age Customer Gender       Product Purchased Date of Purchase  \
# 0               32           Other              GoPro Hero       2021-03-22
# 1               42          Female             LG Smart TV       2021-05-22
# 2               48           Other                Dell XPS       2020-07-14
# 3               27          Female        Microsoft Office       2020-11-13
# 4               67          Female        Autodesk AutoCAD       2020-02-04
# ...            ...             ...                     ...              ...
# 8464            22          Female                 LG OLED       2021-12-08
# 8465            27          Female  Bose SoundLink Speaker       2020-02-22
# 8466            57          Female     GoPro Action Camera       2021-08-17
# 8467            54            Male             PlayStation       2021-10-16
# 8468            53           Other      Philips Hue Lights       2020-06-01
#
#           Ticket Type            Ticket Subject  \
# 0     Technical issue             Product setup
# 1     Technical issue  Peripheral compatibility
# 2     Technical issue           Network problem
# 3     Billing inquiry            Account access
# 4     Billing inquiry                 Data loss
# ...               ...                       ...
# 8464  Product inquiry      Installation support
# 8465  Technical issue            Refund request
# 8466  Technical issue            Account access
# 8467  Product inquiry             Payment issue
# 8468  Billing inquiry            Hardware issue
#
#                                      Ticket Description  \
# 0     I'm having an issue with the {product_purchase...
# 1     I'm having an issue with the {product_purchase...
# 2     I'm facing a problem with my {product_purchase...
# 3     I'm having an issue with the {product_purchase...
# 4     I'm having an issue with the {product_purchase...
# ...                                                 ...
# 8464  My {product_purchased} is making strange noise...
# 8465  I'm having an issue with the {product_purchase...
# 8466  I'm having an issue with the {product_purchase...
# 8467  I'm having an issue with the {product_purchase...
# 8468  There seems to be a hardware problem with my {...
#
#                   Ticket Status  \
# 0     Pending Customer Response
# 1     Pending Customer Response
# 2                        Closed
# 3                        Closed
# 4                        Closed
# ...                         ...
# 8464                       Open
# 8465                       Open
# 8466                     Closed
# 8467                     Closed
# 8468                       Open
#
#                                          Resolution Ticket Priority  \
# 0                                               NaN        Critical
# 1                                               NaN        Critical
# 2      Case maybe show recently my computer follow.             Low
# 3     Try capital clearly never color toward story.             Low
# 4                       West decision evidence bit.             Low
# ...                                             ...             ...
# 8464                                            NaN             Low
# 8465                                            NaN        Critical
# 8466          Eight account century nature kitchen.            High
# 8467                          We seat culture plan.          Medium
# 8468                                            NaN            High
#
#      Ticket Channel  First Response Time   Time to Resolution  \
# 0      Social media  2023-06-01 12:15:36                  NaN
# 1              Chat  2023-06-01 16:45:38                  NaN
# 2      Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3      Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Email  2023-06-01 00:12:42  2023-06-01 19:53:42
# ...             ...                  ...                  ...
# 8464          Phone                  NaN                  NaN
# 8465          Email                  NaN                  NaN
# 8466   Social media  2023-06-01 09:44:22  2023-06-01 04:31:22
# 8467          Email  2023-06-01 18:28:24  2023-06-01 05:32:24
# 8468          Phone                  NaN                  NaN
#
#       Customer Satisfaction Rating
# 0                              NaN
# 1                              NaN
# 2                              3.0
# 3                              3.0
# 4                              1.0
# ...                            ...
# 8464                           NaN
# 8465                           NaN
# 8466                           3.0
# 8467                           3.0
# 8468                           NaN
#
# [8469 rows x 17 columns]>

# %%
df.info
# Out:
# <bound method DataFrame.info of       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age Customer Gender       Product Purchased Date of Purchase  \
# 0               32           Other              GoPro Hero       2021-03-22
# 1               42          Female             LG Smart TV       2021-05-22
# 2               48           Other                Dell XPS       2020-07-14
# 3               27          Female        Microsoft Office       2020-11-13
# 4               67          Female        Autodesk AutoCAD       2020-02-04
# ...            ...             ...                     ...              ...
# 8464            22          Female                 LG OLED       2021-12-08
# 8465            27          Female  Bose SoundLink Speaker       2020-02-22
# 8466            57          Female     GoPro Action Camera       2021-08-17
# 8467            54            Male             PlayStation       2021-10-16
# 8468            53           Other      Philips Hue Lights       2020-06-01
#
#           Ticket Type            Ticket Subject  \
# 0     Technical issue             Product setup
# 1     Technical issue  Peripheral compatibility
# 2     Technical issue           Network problem
# 3     Billing inquiry            Account access
# 4     Billing inquiry                 Data loss
# ...               ...                       ...
# 8464  Product inquiry      Installation support
# 8465  Technical issue            Refund request
# 8466  Technical issue            Account access
# 8467  Product inquiry             Payment issue
# 8468  Billing inquiry            Hardware issue
#
#                                      Ticket Description  \
# 0     I'm having an issue with the {product_purchase...
# 1     I'm having an issue with the {product_purchase...
# 2     I'm facing a problem with my {product_purchase...
# 3     I'm having an issue with the {product_purchase...
# 4     I'm having an issue with the {product_purchase...
# ...                                                 ...
# 8464  My {product_purchased} is making strange noise...
# 8465  I'm having an issue with the {product_purchase...
# 8466  I'm having an issue with the {product_purchase...
# 8467  I'm having an issue with the {product_purchase...
# 8468  There seems to be a hardware problem with my {...
#
#                   Ticket Status  \
# 0     Pending Customer Response
# 1     Pending Customer Response
# 2                        Closed
# 3                        Closed
# 4                        Closed
# ...                         ...
# 8464                       Open
# 8465                       Open
# 8466                     Closed
# 8467                     Closed
# 8468                       Open
#
#                                          Resolution Ticket Priority  \
# 0                                               NaN        Critical
# 1                                               NaN        Critical
# 2      Case maybe show recently my computer follow.             Low
# 3     Try capital clearly never color toward story.             Low
# 4                       West decision evidence bit.             Low
# ...                                             ...             ...
# 8464                                            NaN             Low
# 8465                                            NaN        Critical
# 8466          Eight account century nature kitchen.            High
# 8467                          We seat culture plan.          Medium
# 8468                                            NaN            High
#
#      Ticket Channel  First Response Time   Time to Resolution  \
# 0      Social media  2023-06-01 12:15:36                  NaN
# 1              Chat  2023-06-01 16:45:38                  NaN
# 2      Social media  2023-06-01 11:14:38  2023-06-01 18:05:38
# 3      Social media  2023-06-01 07:29:40  2023-06-01 01:57:40
# 4             Email  2023-06-01 00:12:42  2023-06-01 19:53:42
# ...             ...                  ...                  ...
# 8464          Phone                  NaN                  NaN
# 8465          Email                  NaN                  NaN
# 8466   Social media  2023-06-01 09:44:22  2023-06-01 04:31:22
# 8467          Email  2023-06-01 18:28:24  2023-06-01 05:32:24
# 8468          Phone                  NaN                  NaN
#
#       Customer Satisfaction Rating
# 0                              NaN
# 1                              NaN
# 2                              3.0
# 3                              3.0
# 4                              1.0
# ...                            ...
# 8464                           NaN
# 8465                           NaN
# 8466                           3.0
# 8467                           3.0
# 8468                           NaN
#
# [8469 rows x 17 columns]>

# %%
df.isna().sum()
# Out:
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Product Purchased                  0
# Date of Purchase                   0
# Ticket Type                        0
# Ticket Subject                     0
# Ticket Description                 0
# Ticket Status                      0
# Resolution                      5700
# Ticket Priority                    0
# Ticket Channel                     0
# First Response Time             2819
# Time to Resolution              5700
# Customer Satisfaction Rating    5700
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Resolution"].isnull().sum()
# Out:
# np.int64(5700)

# %%
missing = df["Resolution"].isnull().sum()
total = len(df)

print((missing/total)*100)
# Out:
# 67.30428622033298

# %%
df.drop("Resolution", axis=1, inplace=True)
df.drop('Time to Resolution',axis=1,inplace=True)

# %%
df['Customer Satisfaction Rating']
# Out:
# 0       NaN
# 1       NaN
# 2       3.0
# 3       3.0
# 4       1.0
#        ...
# 8464    NaN
# 8465    NaN
# 8466    3.0
# 8467    3.0
# 8468    NaN
# Name: Customer Satisfaction Rating, Length: 8469, dtype: float64

# %%
df['Customer Satisfaction Rating'] = df['Customer Satisfaction Rating'].fillna(df['Customer Satisfaction Rating'].mode()[0])
df['Customer Satisfaction Rating']
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       1.0
#        ...
# 8464    3.0
# 8465    3.0
# 8466    3.0
# 8467    3.0
# 8468    3.0
# Name: Customer Satisfaction Rating, Length: 8469, dtype: float64

# %% [markdown]
# ### Graphs

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Ticket Type',data=df)
plt.xticks(rotation=45)
plt.title("Ticket Type Distribution")
plt.show()

# %%
df
# Out:
#       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age Customer Gender       Product Purchased Date of Purchase  \
# 0               32           Other              GoPro Hero       2021-03-22
# 1               42          Female             LG Smart TV       2021-05-22
# 2               48           Other                Dell XPS       2020-07-14
# 3               27          Female        Microsoft Office       2020-11-13
# 4               67          Female        Autodesk AutoCAD       2020-02-04
# ...            ...             ...                     ...              ...
# 8464            22          Female                 LG OLED       2021-12-08
# 8465            27          Female  Bose SoundLink Speaker       2020-02-22
# 8466            57          Female     GoPro Action Camera       2021-08-17
# 8467            54            Male             PlayStation       2021-10-16
# 8468            53           Other      Philips Hue Lights       2020-06-01
#
#           Ticket Type            Ticket Subject  \
# 0     Technical issue             Product setup
# 1     Technical issue  Peripheral compatibility
# 2     Technical issue           Network problem
# 3     Billing inquiry            Account access
# 4     Billing inquiry                 Data loss
# ...               ...                       ...
# 8464  Product inquiry      Installation support
# 8465  Technical issue            Refund request
# 8466  Technical issue            Account access
# 8467  Product inquiry             Payment issue
# 8468  Billing inquiry            Hardware issue
#
#                                      Ticket Description  \
# 0     I'm having an issue with the {product_purchase...
# 1     I'm having an issue with the {product_purchase...
# 2     I'm facing a problem with my {product_purchase...
# 3     I'm having an issue with the {product_purchase...
# 4     I'm having an issue with the {product_purchase...
# ...                                                 ...
# 8464  My {product_purchased} is making strange noise...
# 8465  I'm having an issue with the {product_purchase...
# 8466  I'm having an issue with the {product_purchase...
# 8467  I'm having an issue with the {product_purchase...
# 8468  There seems to be a hardware problem with my {...
#
#                   Ticket Status Ticket Priority Ticket Channel  \
# 0     Pending Customer Response        Critical   Social media
# 1     Pending Customer Response        Critical           Chat
# 2                        Closed             Low   Social media
# 3                        Closed             Low   Social media
# 4                        Closed             Low          Email
# ...                         ...             ...            ...
# 8464                       Open             Low          Phone
# 8465                       Open        Critical          Email
# 8466                     Closed            High   Social media
# 8467                     Closed          Medium          Email
# 8468                       Open            High          Phone
#
#       First Response Time  Customer Satisfaction Rating
# 0     2023-06-01 12:15:36                           3.0
# 1     2023-06-01 16:45:38                           3.0
# 2     2023-06-01 11:14:38                           3.0
# 3     2023-06-01 07:29:40                           3.0
# 4     2023-06-01 00:12:42                           1.0
# ...                   ...                           ...
# 8464                  NaN                           3.0
# 8465                  NaN                           3.0
# 8466  2023-06-01 09:44:22                           3.0
# 8467  2023-06-01 18:28:24                           3.0
# 8468                  NaN                           3.0
#
# [8469 rows x 15 columns]

# %%
sns.countplot(x='Ticket Channel',data=df,color='yellow')
plt.title('Ticket Channel')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
# Out:
# Text(0, 0.5, 'yaxis')

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Ticket Status',data=df,color='purple')
plt.title('Ticket Status')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
# Out:
# Text(0, 0.5, 'yaxis')

# %%
priority = df['Ticket Priority'].value_counts()
labels=['Low','Medium','High','Critical']
colors=['orange','teal','gold','lightcoral']

plt.figure(figsize=(6,6))
plt.pie(priority,
        labels=labels,
        colors=colors,
        autopct='%1.1f%%',
        explode=(0,0.1,0,0),
        startangle=90)


plt.title("Ticket Priority")
plt.show()

# %%
plt.figure(figsize=(6,6))
gender = df['Customer Gender'].value_counts()
labels = ['Male','Female','others']
colors = ['red','yellow','green']
plt.pie(gender,
        labels=gender.index,
        colors=colors,
        autopct='%1.1f%%',
        explode=(0,0.1,0),
        startangle=45)
plt.title('gender')
plt.show()

# %%
plt.figure(figsize=(7,5))

plt.hist(df['Customer Satisfaction Rating'],
         bins=10,color='brown')

plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.title("Customer Satisfaction Distribution")

plt.show()

# %%
! pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wordcloud) (2.3.5)
# Requirement already satisfied: pillow in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wordcloud) (12.1.0)
# Requirement already satisfied: matplotlib in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from wordcloud) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\kashi\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: C:\Users\kashi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df['Ticket Description'].astype(str))

wordcloud = WordCloud(
    width=1000,
    height=500,
    background_color='white'
).generate(text)

plt.figure(figsize=(12,6))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(10,6))#data:Correlation matrix

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,#annot=True	Values 
    
    cmap='coolwarm',#cmap='coolwarm'	Color theme
    fmt=".2f",#fmt=".2f"	2 decimal places
    linewidths=0.5,#linewidths=0.5	Cell border width
    linecolor='black'#linecolor='black'	Border color
)

plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# ✔ Ticket ID ka kisi bhi variable se relation nahi hai.
#
# ✔ Customer Age aur Customer Satisfaction me bhi koi significant relationship nahi hai.
#
# ✔ Dataset me koi strong positive ya negative correlation nahi mila.
#
# ✔ Sirf diagonal values 1 hain kyunki har feature ka khud se correlation perfect hota hai.

# %%
plt.figure(figsize=(8,6))

sns.boxplot(
    data=df,
    x='Ticket Priority',
    y='Customer Satisfaction Rating',
    palette='Set2',#color theme
    width=0.5,
    showmeans=True,# shows mwan
    meanprops={#customize mean marker
        "marker":"o",
        "markerfacecolor":"red",
        "markeredgecolor":"black",
        "markersize":8
    }
)

plt.title("Customer Satisfaction by Ticket Priority")
plt.xlabel("Ticket Priority")
plt.ylabel("Customer Satisfaction Rating")

plt.show()
# Out:
# C:\Users\kashi\AppData\Local\Temp\ipykernel_13776\3809608298.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# 1. Red dot > Median → Mean greater than median → High values average ko upar le ja rahi hain.
# 2. Red dot < Median → Mean less than median → Low values average ko neeche le ja rahi hain.
# 3. Red dot ≈ Median → Data roughly symmetric (balanced).

# %% [markdown]
# 1. Median satisfaction rating is 3 for all ticket priorities.
# 2. Mean and median are nearly equal, indicating a fairly symmetric distribution.
# 3. No significant outliers are observed.
# 4. Customer satisfaction does not vary much across ticket priority levels.

# %% [markdown]
# "The red dot represents the mean, while the line inside the box represents the median. A slight difference between them indicates a small amount of skewness in the data. In this graph, the difference is very small, which suggests that the customer satisfaction ratings are fairly balanced across all ticket priorities."

# %% [markdown]
# ### Data cleaning

# %%
df.isna().sum()
# Out:
# Ticket ID                          0
# Customer Name                      0
# Customer Email                     0
# Customer Age                       0
# Customer Gender                    0
# Product Purchased                  0
# Date of Purchase                   0
# Ticket Type                        0
# Ticket Subject                     0
# Ticket Description                 0
# Ticket Status                      0
# Ticket Priority                    0
# Ticket Channel                     0
# First Response Time             2819
# Customer Satisfaction Rating       0
# dtype: int64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
import re
##remove urls
df["Customer Email"] = df["Customer Email"].str.replace(
    r"http\S+|www\S+",
    "",
    regex=True
)

# %%
### for emoji 
emoji_pattern = re.compile(
    "["
    "\U0001F600-\U0001F64F"
    "\U0001F300-\U0001F5FF"
    "\U0001F680-\U0001F6FF"
    "\U0001F1E0-\U0001F1FF"
    "]+",
    flags=re.UNICODE
)

df["Ticket Description"] = df["Ticket Description"].apply(
    lambda x: emoji_pattern.sub("", str(x))
)

# %%
import string


def clean_text(text):
    text = str(text).lower()              # lowercase
    text = re.sub(r"http\S+", "", text)   # remove URLs
    text = re.sub(r"[^a-zA-Z\s]", " ", text)  # keep only letters & spaces
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r"\s+", " ", text).strip()  # remove extra spaces
    return text

# %%
df
# Out:
#       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age Customer Gender       Product Purchased Date of Purchase  \
# 0               32           Other              GoPro Hero       2021-03-22
# 1               42          Female             LG Smart TV       2021-05-22
# 2               48           Other                Dell XPS       2020-07-14
# 3               27          Female        Microsoft Office       2020-11-13
# 4               67          Female        Autodesk AutoCAD       2020-02-04
# ...            ...             ...                     ...              ...
# 8464            22          Female                 LG OLED       2021-12-08
# 8465            27          Female  Bose SoundLink Speaker       2020-02-22
# 8466            57          Female     GoPro Action Camera       2021-08-17
# 8467            54            Male             PlayStation       2021-10-16
# 8468            53           Other      Philips Hue Lights       2020-06-01
#
#           Ticket Type            Ticket Subject  \
# 0     Technical issue             Product setup
# 1     Technical issue  Peripheral compatibility
# 2     Technical issue           Network problem
# 3     Billing inquiry            Account access
# 4     Billing inquiry                 Data loss
# ...               ...                       ...
# 8464  Product inquiry      Installation support
# 8465  Technical issue            Refund request
# 8466  Technical issue            Account access
# 8467  Product inquiry             Payment issue
# 8468  Billing inquiry            Hardware issue
#
#                                      Ticket Description  \
# 0     I'm having an issue with the {product_purchase...
# 1     I'm having an issue with the {product_purchase...
# 2     I'm facing a problem with my {product_purchase...
# 3     I'm having an issue with the {product_purchase...
# 4     I'm having an issue with the {product_purchase...
# ...                                                 ...
# 8464  My {product_purchased} is making strange noise...
# 8465  I'm having an issue with the {product_purchase...
# 8466  I'm having an issue with the {product_purchase...
# 8467  I'm having an issue with the {product_purchase...
# 8468  There seems to be a hardware problem with my {...
#
#                   Ticket Status Ticket Priority Ticket Channel  \
# 0     Pending Customer Response        Critical   Social media
# 1     Pending Customer Response        Critical           Chat
# 2                        Closed             Low   Social media
# 3                        Closed             Low   Social media
# 4                        Closed             Low          Email
# ...                         ...             ...            ...
# 8464                       Open             Low          Phone
# 8465                       Open        Critical          Email
# 8466                     Closed            High   Social media
# 8467                     Closed          Medium          Email
# 8468                       Open            High          Phone
#
#       First Response Time  Customer Satisfaction Rating
# 0     2023-06-01 12:15:36                           3.0
# 1     2023-06-01 16:45:38                           3.0
# 2     2023-06-01 11:14:38                           3.0
# 3     2023-06-01 07:29:40                           3.0
# 4     2023-06-01 00:12:42                           1.0
# ...                   ...                           ...
# 8464                  NaN                           3.0
# 8465                  NaN                           3.0
# 8466  2023-06-01 09:44:22                           3.0
# 8467  2023-06-01 18:28:24                           3.0
# 8468                  NaN                           3.0
#
# [8469 rows x 15 columns]

# %% [markdown]
# ### Vectorization

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Customer Gender'] = le.fit_transform(df['Customer Gender'])
df['Product Purchased'] = le.fit_transform(df['Product Purchased'])
df['Ticket Type'] = le.fit_transform(df['Ticket Type'])
df['Ticket Status'] = le.fit_transform(df['Ticket Status'])

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=2500,ngram_range=(1,2))
x = cv.fit_transform(df['Ticket Description'])

# %%
df
# Out:
#       Ticket ID        Customer Name              Customer Email  \
# 0             1        Marisa Obrien  carrollallison@example.com
# 1             2         Jessica Rios    clarkeashley@example.com
# 2             3  Christopher Robbins   gonzalestracy@example.com
# 3             4     Christina Dillon    bradleyolson@example.org
# 4             5    Alexander Carroll     bradleymark@example.com
# ...         ...                  ...                         ...
# 8464       8465           David Todd          adam28@example.net
# 8465       8466           Lori Davis       russell68@example.com
# 8466       8467      Michelle Kelley        ashley83@example.org
# 8467       8468     Steven Rodriguez         fpowell@example.org
# 8468       8469      Steven Davis MD          lori20@example.net
#
#       Customer Age  Customer Gender  Product Purchased Date of Purchase  \
# 0               32                2                 16       2021-03-22
# 1               42                0                 21       2021-05-22
# 2               48                2                 10       2020-07-14
# 3               27                0                 25       2020-11-13
# 4               67                0                  5       2020-02-04
# ...            ...              ...                ...              ...
# 8464            22                0                 20       2021-12-08
# 8465            27                0                  7       2020-02-22
# 8466            57                0                 15       2021-08-17
# 8467            54                1                 33       2021-10-16
# 8468            53                2                 32       2020-06-01
#
#       Ticket Type            Ticket Subject  \
# 0               4             Product setup
# 1               4  Peripheral compatibility
# 2               4           Network problem
# 3               0            Account access
# 4               0                 Data loss
# ...           ...                       ...
# 8464            2      Installation support
# 8465            4            Refund request
# 8466            4            Account access
# 8467            2             Payment issue
# 8468            0            Hardware issue
#
#                                      Ticket Description  Ticket Status  \
# 0     I'm having an issue with the {product_purchase...              2
# 1     I'm having an issue with the {product_purchase...              2
# 2     I'm facing a problem with my {product_purchase...              0
# 3     I'm having an issue with the {product_purchase...              0
# 4     I'm having an issue with the {product_purchase...              0
# ...                                                 ...            ...
# 8464  My {product_purchased} is making strange noise...              1
# 8465  I'm having an issue with the {product_purchase...              1
# 8466  I'm having an issue with the {product_purchase...              0
# 8467  I'm having an issue with the {product_purchase...              0
# 8468  There seems to be a hardware problem with my {...              1
#
#      Ticket Priority Ticket Channel  First Response Time  \
# 0           Critical   Social media  2023-06-01 12:15:36
# 1           Critical           Chat  2023-06-01 16:45:38
# 2                Low   Social media  2023-06-01 11:14:38
# 3                Low   Social media  2023-06-01 07:29:40
# 4                Low          Email  2023-06-01 00:12:42
# ...              ...            ...                  ...
# 8464             Low          Phone                  NaN
# 8465        Critical          Email                  NaN
# 8466            High   Social media  2023-06-01 09:44:22
# 8467          Medium          Email  2023-06-01 18:28:24
# 8468            High          Phone                  NaN
#
#       Customer Satisfaction Rating
# 0                              3.0
# 1                              3.0
# 2                              3.0
# 3                              3.0
# 4                              1.0
# ...                            ...
# 8464                           3.0
# 8465                           3.0
# 8466                           3.0
# 8467                           3.0
# 8468                           3.0
#
# [8469 rows x 15 columns]

# %%
import numpy as np
np.set_printoptions(edgeitems=40,linewidth=100000,formatter=dict(float=lambda x:"%.3g"% x))
x
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 556999 stored elements and shape (8469, 2500)>

# %%
# x = df.drop(df['Customer Satisfaction Rating'])
# x
# Out:
#       Ticket ID      Customer Name              Customer Email  Customer Age  \
# 0             1      Marisa Obrien  carrollallison@example.com            32
# 6             7  Jacqueline Wright     donaldkeith@example.org            24
# 7             8         Denise Lee    joelwilliams@example.com            23
# 8             9     Nicolas Wilson        joshua24@example.com            60
# 9            10     William Dawson          clopez@example.com            27
# ...         ...                ...                         ...           ...
# 8464       8465         David Todd          adam28@example.net            22
# 8465       8466         Lori Davis       russell68@example.com            27
# 8466       8467    Michelle Kelley        ashley83@example.org            57
# 8467       8468   Steven Rodriguez         fpowell@example.org            54
# 8468       8469    Steven Davis MD          lori20@example.net            53
#
#       Customer Gender  Product Purchased Date of Purchase  Ticket Type  \
# 0                   2                 16       2021-03-22            4
# 6                   2                 26       2020-02-23            2
# 7                   1                 32       2020-08-09            3
# 8                   2                 13       2020-07-16            4
# 9                   1                 11       2020-03-06            3
# ...               ...                ...              ...          ...
# 8464                0                 20       2021-12-08            2
# 8465                0                  7       2020-02-22            4
# 8466                0                 15       2021-08-17            4
# 8467                1                 33       2021-10-16            2
# 8468                2                 32       2020-06-01            0
#
#             Ticket Subject                                 Ticket Description  \
# 0            Product setup  I'm having an issue with the {product_purchase...
# 6           Refund request  I'm unable to access my {product_purchased} ac...
# 7             Battery life  I'm having an issue with the {product_purchase...
# 8     Installation support  I'm having an issue with the {product_purchase...
# 9            Payment issue  My {product_purchased} is making strange noise...
# ...                    ...                                                ...
# 8464  Installation support  My {product_purchased} is making strange noise...
# 8465        Refund request  I'm having an issue with the {product_purchase...
# 8466        Account access  I'm having an issue with the {product_purchase...
# 8467         Payment issue  I'm having an issue with the {product_purchase...
# 8468        Hardware issue  There seems to be a hardware problem with my {...
#
#       Ticket Status Ticket Priority Ticket Channel  First Response Time  \
# 0                 2        Critical   Social media  2023-06-01 12:15:36
# 6                 1        Critical   Social media                  NaN
# 7                 1        Critical   Social media                  NaN
# 8                 2             Low   Social media  2023-06-01 10:32:47
# 9                 2        Critical          Phone  2023-06-01 09:25:48
# ...             ...             ...            ...                  ...
# 8464              1             Low          Phone                  NaN
# 8465              1        Critical          Email                  NaN
# 8466              0            High   Social media  2023-06-01 09:44:22
# 8467              0          Medium          Email  2023-06-01 18:28:24
# 8468              1            High          Phone                  NaN
#
#       Customer Satisfaction Rating
# 0                              3.0
# 6                              3.0
# 7                              3.0
# 8                              3.0
# 9                              3.0
# ...                            ...
# 8464                           3.0
# 8465                           3.0
# 8466                           3.0
# 8467                           3.0
# 8468                           3.0
#
# [8464 rows x 15 columns]

# %%
y = df['Customer Satisfaction Rating']
y
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       3.0
# 4       1.0
#        ...
# 8464    3.0
# 8465    3.0
# 8466    3.0
# 8467    3.0
# 8468    3.0
# Name: Customer Satisfaction Rating, Length: 8469, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB
customerrating = MultinomialNB().fit(x_train,y_train)
y_pre = customerrating.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test,y_pre))
print(classification_report(y_test,y_pre))
# Out:
# [[ 21  27  36  21  10]
#  [ 14  19  47  13  16]
#  [145 225 552 181 134]
#  [ 13  28  55  16  14]
#  [ 10  21  51  14  11]]
#               precision    recall  f1-score   support
#
#          1.0       0.10      0.18      0.13       115
#          2.0       0.06      0.17      0.09       109
#          3.0       0.74      0.45      0.56      1237
#          4.0       0.07      0.13      0.09       126
#          5.0       0.06      0.10      0.08       107
#
#     accuracy                           0.37      1694
#    macro avg       0.21      0.21      0.19      1694
# weighted avg       0.56      0.37      0.43      1694
